# %%
print("hello")
# Out:
# hello

# %%
from select_ts.ctd import find_min_ts
import pandas as pd
df = pd.read_csv("../Results/multi_model/qwen_no_think_c=1--55_x=55_benchmark_v3.csv")
df_gem = df[df["model"] == ""]
for i in range(1,56):
    min_ts = find_min_ts(i)
